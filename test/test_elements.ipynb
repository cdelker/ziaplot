# %%
import numpy as np

import ziaplot as zp

# %%
x = np.linspace(-10, 10, 20)
y = np.random.normal(x, 1)

# %%
# Individual Line repr creates a Graph to plot on
zp.Plot(x, y).name('Data')

# %%
zp.Xy(x, y).name('Data')

# %%
x = zp.linspace(0, 10, 20)
y = x

# %%
# Markers
p = zp.Graph().axesnames('X', 'Y').title('Title')
p += zp.Xy(x, y).name('Data').marker('round')
p += zp.Xy(x, [yy*2 for yy in y]).name('Data 2').marker('square')
p += zp.Xy(x, [yy*3 for yy in y]).name('Data 3').marker('triangle')
p += zp.Xy(x, [yy*4 for yy in y]).name('Data 4').marker('triangled')
p += zp.Xy(x, [yy*5 for yy in y]).name('Data 5').marker('+')
p += zp.Xy(x, [yy*6 for yy in y]).name('Data 6').marker('x')
p

# %%
# Strokes
p = zp.Graph().axesnames('X', 'Y').title('Title')
p += zp.Plot(x, y).name('Data').stroke('-').strokewidth(3)
p += zp.Plot(x, [yy*2 for yy in y]).name('Data 2').stroke('dashed').strokewidth(5)
p += zp.Plot(x, [yy*3 for yy in y]).name('Data 3').stroke('dotted').strokewidth(2)
p += zp.Plot(x, [yy*4 for yy in y]).name('Data 4').stroke('dashdot').strokewidth(1)
p += zp.Plot(x, [yy*5 for yy in y]).name('Data 5').stroke('5 5 10').strokewidth(6)
p

# %%
# Colors
p = zp.Graph().axesnames('X', 'Y').title('Title')
p += zp.Plot(x, y).name('Data').color('red')  # Named
p += zp.Plot(x, [yy*2 for yy in y]).name('Data 2').color('#0000FF')  # Hex
p += zp.Plot(x, [yy*3 for yy in y]).name('Data 3').color('C0')  # Theme
p += zp.Plot(x, [yy*4 for yy in y]).name('Data 4').color('C1')
p

# %%
# H/VLine
p = zp.Graph()
p += zp.HLine(0)
p += zp.VLine(1)
p

# %%
# Text
p = zp.Graph()
p += zp.Xy(x, y).marker('round', radius=3)
p += zp.Text(2, 4, '(2, 3)')
p += zp.Text(4, 6, '(4, 5)').color('red')
p += zp.Text(4, 2, 'center', halign='center', valign='center')
p += zp.Text(6, 2, 'topleft', halign='left', valign='top')
p += zp.Text(8, 2, 'botright', halign='right', valign='bottom')
p += zp.Text(6, 8, 'rotate', rotate=40).color('blue')
p

# %%
x = np.arange(1, 10)
y = x
zp.Bars(x, y)

# %%
zp.BarsHoriz(x, y, width=.5)

# %%
y = np.random.normal(100, 5, 1000)
h1 = zp.Histogram(y)
h2 = zp.Histogram(y, bins=10, density=True)
h3 = zp.Histogram(y, binrange=(90, 110, 1))
h4 = zp.Histogram(y, weights=np.ones_like(y)*100)

zp.LayoutGrid(h1, h2, h3, h4, columns=2)

# %%
x = np.linspace(0, 10, 40)
y1 = x + np.random.normal(0, .5, len(x))
y2 = 3*x + 5 + np.random.normal(0, .5, len(x))

p = zp.Graph()
p += zp.LineFill(x, y1, y2).fill('orange 20%').marker('round', 3)
p += zp.LineFill(x, y1/2).fill('purple 20%').color('black')
p

# %%
x = np.linspace(0, 10, 10)
y = x*2
dy = y/10
dx = np.full(len(x), .5)

p = zp.Graph()
p += zp.ErrorBar(x, y, dy)
p2 = zp.Graph()
p2 += zp.ErrorBar(x, y, xerr=dx)
zp.LayoutH(p, p2)

# %%
p = zp.Graph()
p.css('''
ErrorBar.MarkerYError {stroke: dotted; edge_width: 5; radius: 20; color: blue;}
''')
p += zp.ErrorBar(x, y, dy)
p

# %%
p = zp.Graph()
p.css('''
ErrorBar.MarkerXError {stroke: dotted; edge_width: 5; radius: 20; color: blue;}
''')
p += zp.ErrorBar(x, y, xerr=dy)
p

# %%
p = zp.Graph()
p.css('ErrorBar.MarkerYError {shape: round; radius: 4}')
p += zp.ErrorBar(x, y, dy)
p

# %%
delta = 0.05
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-1.5, 2.5, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2

with zp.LayoutGrid(columns=2).size(800, 600):
    zp.Contour(x, y, Z, colorbar='top')
    zp.Contour(x, y, Z, levels=5, colorbar='bottom')
    p = zp.Contour(x, y, Z, levels=13, colorbar='left')
    zp.Contour(x, y, Z, colorbar='right')
